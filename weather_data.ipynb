# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\keerthana\Downloads\weather_data.csv")

# %%
print("--- Dataset Overview ---")
print(df.head())
print("\n--- Data Info ---")
print(df.info())
# Out:
# --- Dataset Overview ---
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog
#
# --- Data Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ...

# %%
# Convert Date/Time column to datetime objects
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

# Check for missing values
print("\nMissing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
clear_weather = df[df['Weather'] == 'Clear']
print(f"\nNumber of clear days: {len(clear_weather)}")

# Example: Find the mean Visibility
mean_visibility = df['Visibility_km'].mean()
print(f"Average Visibility: {mean_visibility:.2f} km")
# Out:
# Number of clear days: 1326
# Average Visibility: 27.66 km

# %%
plt.figure(figsize=(12, 6))

# Plotting Temperature Trends
sns.lineplot(data=df.head(500), x='Date/Time', y='Temp_C')
plt.title('Temperature Trend (First 500 records)')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))

numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

plt.title('Correlation between Weather Variables')
plt.show()
